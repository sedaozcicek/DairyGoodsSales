# %% [markdown]
# <a href="https://colab.research.google.com/github/sedaozcicek/DairyGoodsSales/blob/main/dairyGoodsSalesDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/dairy_dataset.csv")

# %%
df
# Out:
#            Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0         Telangana                   310.84              96    Medium
# 1     Uttar Pradesh                    19.19              44     Large
# 2        Tamil Nadu                   581.69              24    Medium
# 3         Telangana                   908.00              89     Small
# 4       Maharashtra                   861.95              21    Medium
# ...             ...                      ...             ...       ...
# 4320          Delhi                   748.71              89    Medium
# 4321      Jharkhand                   385.91              29     Large
# 4322     Chandigarh                   311.54              65     Small
# 4323    Maharashtra                   890.55              90     Small
# 4324      Rajasthan                   492.86              58     Large
#
#             Date  Product ID Product Name                 Brand  \
# ...

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  2022-02-17           5    Ice Cream           Dodla Dairy
# 1  2021-12-01           1         Milk                  Amul
# 2  2022-02-28           4       Yogurt           Dodla Dairy
# 3  2019-06-09           3       Cheese  Britannia Industries
# 4  2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       2021-12-27
# ...

# %%
df.dtypes
# Out:
# Location                                object
# Total Land Area (acres)                float64
# Number of Cows                           int64
# Farm Size                               object
# Date                                    object
# Product ID                               int64
# Product Name                            object
# Brand                                   object
# Quantity (liters/kg)                   float64
# Price per Unit                         float64
# Total Value                            float64
# Shelf Life (days)                        int64
# Storage Condition                       object
# Production Date                         object
# Expiration Date                         object
# Quantity Sold (liters/kg)                int64
# Price per Unit (sold)                  float64
# Approx. Total Revenue(INR)             float64
# Customer Location                       object
# Sales Channel                           object
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Location                               0
# Total Land Area (acres)                0
# Number of Cows                         0
# Farm Size                              0
# Date                                   0
# Product ID                             0
# Product Name                           0
# Brand                                  0
# Quantity (liters/kg)                   0
# Price per Unit                         0
# Total Value                            0
# Shelf Life (days)                      0
# Storage Condition                      0
# Production Date                        0
# Expiration Date                        0
# Quantity Sold (liters/kg)              0
# Price per Unit (sold)                  0
# Approx. Total Revenue(INR)             0
# Customer Location                      0
# Sales Channel                          0
# Quantity in Stock (liters/kg)          0
# Minimum Stock Threshold (liters/kg)    0
# Reorder Quantity (liters/kg)           0
# ...

# %%
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['Location', 'Total_Land_Area_(acres)', 'Number_of_Cows', 'Farm_Size',
#        'Date', 'Product_ID', 'Product_Name', 'Brand', 'Quantity_(liters/kg)',
#        'Price_per_Unit', 'Total_Value', 'Shelf_Life_(days)',
#        'Storage_Condition', 'Production_Date', 'Expiration_Date',
#        'Quantity_Sold_(liters/kg)', 'Price_per_Unit_(sold)',
#        'Approx._Total_Revenue(INR)', 'Customer_Location', 'Sales_Channel',
#        'Quantity_in_Stock_(liters/kg)', 'Minimum_Stock_Threshold_(liters/kg)',
#        'Reorder_Quantity_(liters/kg)'],
#       dtype='object')

# %%
 df.shape
# Out:
# (4325, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             4325 non-null   object
#  1   Total_Land_Area_(acres)              4325 non-null   float64
#  2   Number_of_Cows                       4325 non-null   int64
#  3   Farm_Size                            4325 non-null   object
#  4   Date                                 4325 non-null   object
#  5   Product_ID                           4325 non-null   int64
#  6   Product_Name                         4325 non-null   object
#  7   Brand                                4325 non-null   object
#  8   Quantity_(liters/kg)                 4325 non-null   float64
#  9   Price_per_Unit                       4325 non-null   float64
#  10  Total_Value                          4325 non-null   float64
# ...

# %%
 df["Shelf_Life_(days)"].describe().round()
# Out:
# count    4325.0
# mean       29.0
# std        30.0
# min         1.0
# 25%        10.0
# 50%        22.0
# 75%        30.0
# max       150.0
# Name: Shelf_Life_(days), dtype: float64

# %%
print(len(df["Brand"].unique()))
df["Brand"].unique()
# Out:
# 11
# array(['Dodla Dairy', 'Amul', 'Britannia Industries', 'Mother Dairy',
#        'Raj', 'Dynamix Dairies', 'Sudha', 'Passion Cheese', 'Warana',
#        'Palle2patnam', 'Parag Milk Foods'], dtype=object)

# %%
 print(len(df["Product_Name"].unique()))
 df["Product_Name"].unique()
# Out:
# 10
# array(['Ice Cream', 'Milk', 'Yogurt', 'Cheese', 'Buttermilk', 'Curd',
#        'Paneer', 'Lassi', 'Ghee', 'Butter'], dtype=object)

# %%
df.columns
# Out:
# Index(['Location', 'Total_Land_Area_(acres)', 'Number_of_Cows', 'Farm_Size',
#        'Date', 'Product_ID', 'Product_Name', 'Brand', 'Quantity_(liters/kg)',
#        'Price_per_Unit', 'Total_Value', 'Shelf_Life_(days)',
#        'Storage_Condition', 'Production_Date', 'Expiration_Date',
#        'Quantity_Sold_(liters/kg)', 'Price_per_Unit_(sold)',
#        'Approx._Total_Revenue(INR)', 'Customer_Location', 'Sales_Channel',
#        'Quantity_in_Stock_(liters/kg)', 'Minimum_Stock_Threshold_(liters/kg)',
#        'Reorder_Quantity_(liters/kg)'],
#       dtype='object')

# %%
 print(len(df["Location"].unique()))
df.Location.unique()
# Out:
# 15
# array(['Telangana', 'Uttar Pradesh', 'Tamil Nadu', 'Maharashtra',
#        'Karnataka', 'Bihar', 'West Bengal', 'Madhya Pradesh',
#        'Chandigarh', 'Delhi', 'Gujarat', 'Kerala', 'Jharkhand',
#        'Rajasthan', 'Haryana'], dtype=object)

# %%
 print(len(df["Price_per_Unit"].unique()))
df.Price_per_Unit.unique()
# Out:
# 3409
# array([85.72, 42.61, 36.5 , ..., 55.35, 92.61, 15.3 ])

# %%
 print(len(df["Shelf_Life_(days)"].unique()))
df["Shelf_Life_(days)"].unique()
# Out:
# 146
# array([ 25,  22,  30,  72,  11,   5,  83,  14,   6,   9,  24,  69,  28,
#          1, 138,  10,  43,  36,   8,  37,   7,  12, 136, 129,  17,  13,
#          2,  38,  16,  29,  42, 137, 143,  26, 147,  21,  27, 144,  40,
#        135,  59,  39,  85,  44,  82,  23,  74,  33,  81,  50,  55,  32,
#         92,  68,  34,  62,  31,  86,  63,  52,  49, 122,  35, 106, 125,
#        133,  18, 131, 115,  51,  15,  88, 104,  64,  91,  65, 100,  67,
#         66,  53,  61, 126, 145,  70,  77, 128,  75,  87,  99,  90, 139,
#         98,  79, 118, 140,  89, 149, 119, 146,  47, 117,  46,  73,  45,
#         41, 112,  71,  78,  56, 134,  96,  60, 116,  76, 141, 109, 150,
#         57, 130,  95, 127,  94,  93, 132, 108, 101,  80,  48, 142, 113,
#        120,  58,  84,  54, 124, 121, 114, 111, 110, 103, 148, 123, 105,
#         97, 107, 102])

# %%
df["Shelf_Life_(days)"].describe().round()
# Out:
# count    4325.0
# mean       29.0
# std        30.0
# min         1.0
# 25%        10.0
# 50%        22.0
# 75%        30.0
# max       150.0
# Name: Shelf_Life_(days), dtype: float64

# %%
print(len(df["Storage_Condition"].unique()))
df["Storage_Condition"].unique()
# Out:
# 5
# array(['Frozen', 'Tetra Pack', 'Refrigerated', 'Polythene Packet',
#        'Ambient'], dtype=object)

# %%
df["Approx._Total_Revenue(INR)"].describe().round()
# Out:
# count     4325.0
# mean     13580.0
# std      14617.0
# min         13.0
# 25%       2917.0
# 50%       8395.0
# 75%      19505.0
# max      89109.0
# Name: Approx._Total_Revenue(INR), dtype: float64

# %%
  df.describe().round()
# Out:
#        Total_Land_Area_(acres)  Number_of_Cows  Product_ID  \
# count                   4325.0          4325.0      4325.0
# mean                     503.0            55.0         6.0
# std                      286.0            26.0         3.0
# min                       10.0            10.0         1.0
# 25%                      253.0            32.0         3.0
# 50%                      509.0            55.0         6.0
# 75%                      751.0            77.0         8.0
# max                     1000.0           100.0        10.0
#
#        Quantity_(liters/kg)  Price_per_Unit  Total_Value  Shelf_Life_(days)  \
# count                4325.0          4325.0       4325.0             4325.0
# mean                  501.0            55.0      27358.0               29.0
# std                   289.0            26.0      21621.0               30.0
# min                     1.0            10.0         43.0                1.0
# ...

# %%
removed_columns = ["Total_Land_Area_(acres)", "Number_of_Cows"]
df = df.drop(columns=removed_columns)

# %%
  df.describe().round()
# Out:
#        Product_ID  Quantity_(liters/kg)  Price_per_Unit  Total_Value  \
# count      4325.0                4325.0          4325.0       4325.0
# mean          6.0                 501.0            55.0      27358.0
# std           3.0                 289.0            26.0      21621.0
# min           1.0                   1.0            10.0         43.0
# 25%           3.0                 254.0            32.0       9947.0
# 50%           6.0                 498.0            54.0      21870.0
# 75%           8.0                 750.0            77.0      40954.0
# max          10.0                1000.0           100.0      99036.0
#
#        Shelf_Life_(days)  Quantity_Sold_(liters/kg)  Price_per_Unit_(sold)  \
# count             4325.0                     4325.0                 4325.0
# mean                29.0                      248.0                   55.0
# std                 30.0                      217.0                   26.0
# ...

# %%
  df.describe()
# Out:
#         Product_ID  Quantity_(liters/kg)  Price_per_Unit   Total_Value  \
# count  4325.000000           4325.000000     4325.000000   4325.000000
# mean      5.509595            500.652657       54.785938  27357.845411
# std       2.842979            288.975915       26.002815  21621.051594
# min       1.000000              1.170000       10.030000     42.516500
# 25%       3.000000            254.170000       32.460000   9946.814500
# 50%       6.000000            497.550000       54.400000  21869.652900
# 75%       8.000000            749.780000       77.460000  40954.441000
# max      10.000000            999.930000       99.990000  99036.369600
#
#        Shelf_Life_(days)  Quantity_Sold_(liters/kg)  Price_per_Unit_(sold)  \
# count        4325.000000                4325.000000             4325.00000
# mean           29.127630                 248.095029               54.77914
# std            30.272114                 217.024182               26.19279
# ...

# %%
 print(len(df["Location"].unique()))
# Out:
# 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             4325 non-null   object
#  1   Farm_Size                            4325 non-null   object
#  2   Date                                 4325 non-null   object
#  3   Product_ID                           4325 non-null   int64
#  4   Product_Name                         4325 non-null   object
#  5   Brand                                4325 non-null   object
#  6   Quantity_(liters/kg)                 4325 non-null   float64
#  7   Price_per_Unit                       4325 non-null   float64
#  8   Total_Value                          4325 non-null   float64
#  9   Shelf_Life_(days)                    4325 non-null   int64
#  10  Storage_Condition                    4325 non-null   object
# ...

# %%
df["Shelf_Life_(days)"] = df["Shelf_Life_(days)"].astype(str)
df["Shelf_Life_(days)"] = df["Shelf_Life_(days)"].str.replace("(days)", "days")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             4325 non-null   object
#  1   Farm_Size                            4325 non-null   object
#  2   Date                                 4325 non-null   object
#  3   Product_ID                           4325 non-null   int64
#  4   Product_Name                         4325 non-null   object
#  5   Brand                                4325 non-null   object
#  6   Quantity_(liters/kg)                 4325 non-null   float64
#  7   Price_per_Unit                       4325 non-null   float64
#  8   Total_Value                          4325 non-null   float64
#  9   Shelf_Life_days                      4325 non-null   object
#  10  Storage_Condition                    4325 non-null   object
# ...

# %%
print(df.head())
# Out:
#         Location Farm_Size        Date  Product_ID Product_Name  \
# 0      Telangana    Medium  2022-02-17           5    Ice Cream
# 1  Uttar Pradesh     Large  2021-12-01           1         Milk
# 2     Tamil Nadu    Medium  2022-02-28           4       Yogurt
# 3      Telangana     Small  2019-06-09           3       Cheese
# 4    Maharashtra    Medium  2020-12-14           8   Buttermilk
#
#                   Brand  Quantity_(liters/kg)  Price_per_Unit  Total_Value  \
# 0           Dodla Dairy                222.40           85.72   19064.1280
# 1                  Amul                687.48           42.61   29293.5228
# 2           Dodla Dairy                503.48           36.50   18377.0200
# 3  Britannia Industries                823.36           26.52   21835.5072
# 4          Mother Dairy                147.77           83.85   12390.5145
#
#   Shelf_Life_days  ... Production_Date Expiration_Date  \
# 0              25  ...      2021-12-27      2022-01-21
# ...

# %%
df.head()
# Out:
#         Location Farm_Size        Date  Product_ID Product_Name  \
# 0      Telangana    Medium  2022-02-17           5    Ice Cream
# 1  Uttar Pradesh     Large  2021-12-01           1         Milk
# 2     Tamil Nadu    Medium  2022-02-28           4       Yogurt
# 3      Telangana     Small  2019-06-09           3       Cheese
# 4    Maharashtra    Medium  2020-12-14           8   Buttermilk
#
#                   Brand  Quantity_(liters/kg)  Price_per_Unit  Total_Value  \
# 0           Dodla Dairy                222.40           85.72   19064.1280
# 1                  Amul                687.48           42.61   29293.5228
# 2           Dodla Dairy                503.48           36.50   18377.0200
# 3  Britannia Industries                823.36           26.52   21835.5072
# 4          Mother Dairy                147.77           83.85   12390.5145
#
#   Shelf_Life_days  ... Production_Date Expiration_Date  \
# 0              25  ...      2021-12-27      2022-01-21
# ...

# %%
df.rename(columns={"Shelf_Life_days": "Shelf_Life_(days)"}, inplace=True)

# %%
df.head()
# Out:
#         Location Farm_Size        Date  Product_ID Product_Name  \
# 0      Telangana    Medium  2022-02-17           5    Ice Cream
# 1  Uttar Pradesh     Large  2021-12-01           1         Milk
# 2     Tamil Nadu    Medium  2022-02-28           4       Yogurt
# 3      Telangana     Small  2019-06-09           3       Cheese
# 4    Maharashtra    Medium  2020-12-14           8   Buttermilk
#
#                   Brand  Quantity_(liters/kg)  Price_per_Unit  Total_Value  \
# 0           Dodla Dairy                222.40           85.72   19064.1280
# 1                  Amul                687.48           42.61   29293.5228
# 2           Dodla Dairy                503.48           36.50   18377.0200
# 3  Britannia Industries                823.36           26.52   21835.5072
# 4          Mother Dairy                147.77           83.85   12390.5145
#
#   Shelf_Life_(days)  ... Production_Date Expiration_Date  \
# 0                25  ...      2021-12-27      2022-01-21
# ...

# %%
df.rename(columns={"Approx._Total_Revenue(INR)": "Approx_Total_Revenue(INR)"}, inplace=True)

# %%
df.head()
# Out:
#         Location Farm_Size        Date  Product_ID Product_Name  \
# 0      Telangana    Medium  2022-02-17           5    Ice Cream
# 1  Uttar Pradesh     Large  2021-12-01           1         Milk
# 2     Tamil Nadu    Medium  2022-02-28           4       Yogurt
# 3      Telangana     Small  2019-06-09           3       Cheese
# 4    Maharashtra    Medium  2020-12-14           8   Buttermilk
#
#                   Brand  Quantity_(liters/kg)  Price_per_Unit  Total_Value  \
# 0           Dodla Dairy                222.40           85.72   19064.1280
# 1                  Amul                687.48           42.61   29293.5228
# 2           Dodla Dairy                503.48           36.50   18377.0200
# 3  Britannia Industries                823.36           26.52   21835.5072
# 4          Mother Dairy                147.77           83.85   12390.5145
#
#   Shelf_Life_(days)  ... Production_Date Expiration_Date  \
# 0                25  ...      2021-12-27      2022-01-21
# ...

# %%
removed_columns = ["Farm_Size"]
df = df.drop(columns=removed_columns)

# %%
df.head()
# Out:
#         Location        Date  Product_ID Product_Name                 Brand  \
# 0      Telangana  2022-02-17           5    Ice Cream           Dodla Dairy
# 1  Uttar Pradesh  2021-12-01           1         Milk                  Amul
# 2     Tamil Nadu  2022-02-28           4       Yogurt           Dodla Dairy
# 3      Telangana  2019-06-09           3       Cheese  Britannia Industries
# 4    Maharashtra  2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity_(liters/kg)  Price_per_Unit  Total_Value Shelf_Life_(days)  \
# 0                222.40           85.72   19064.1280                25
# 1                687.48           42.61   29293.5228                22
# 2                503.48           36.50   18377.0200                30
# 3                823.36           26.52   21835.5072                72
# 4                147.77           83.85   12390.5145                11
#
#   Storage_Condition Production_Date Expiration_Date  \
# ...

# %%
# @title Sales_Channel vs Quantity_(liters/kg)

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Sales_Channel'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Quantity_(liters/kg)', y='Sales_Channel', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-76-e27d22f67187>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='Quantity_(liters/kg)', y='Sales_Channel', inner='box', palette='Dark2')
